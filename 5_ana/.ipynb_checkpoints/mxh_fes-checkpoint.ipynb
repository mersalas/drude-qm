# %% [markdown]
# # Free energy surface

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde
import matplotlib.colors as mcolors

# constants
T   = 300.0                   # Kelvin
R   = 0.00198720425864083     # kcal/mol/K
eps = 1e-12                   # avoid log(0)


# peptide systems: ( (file, label, (x,y)))
systems = [
    (
        ("1_MHH/pi_select.dat", "π–π", (15, 5.3)),
        ("1_MHH/ce1_select.dat", "CH–π", (130, 4.8)),
        ("1_MHH/hb_select.dat", "H-bond", (95, 1.9)),
        "His$^0$-His$^0$"
    ),
    (
        ("2_MRH/cat_select.dat", "cation–π", (30, 6.3)),
        ("2_MRH/pi_select.dat", "π–π", (8, 3.0)),
        ("2_MRH/hd1_select.dat", "CH–π", (130, 4.8)),
        ("2_MRH/hh11_select.dat", "H-bond", (80, 1.2)),
        "Arg$^+$-His$^0$"
    ),
    (
        ("3_MKH/cat_select.dat", "cation–π", (30, 6.5)),
        ("3_MKH/he1_select.dat", "CH–π", (130, 4.8)),
        ("3_MKH/hz3_select.dat", "H-bond", (80, 1.1)),
        "Lys$^+$-His$^0$"
    ),
    (
        ("4_MOH/cat_select.dat", "cation–π", (45, 5.0)),
        "Orn$^+$-His$^0$"
    ),
    (
        ("5_MbH/cat_select.dat", "cation–π", (30, 6.5)),
        ("5_MbH/hg1_select.dat", "CH–π", (120, 4.8)),
        ("5_MbH/hd2_select.dat", "H-bond", (95, 1.1)),
        "Dab$^+$-His$^0$"
    ),
    (
        ("6_MpH/cat_select.dat", "cation–π", (30, 6.6)),
        ("6_MpH/hb2_select.dat", "CH–π", (120, 3.8)),
        ("6_MpH/hg1_select.dat", "H-bond", (85, 1.2)),
        "Dap$^+$-His$^0$"
    )
]

# grid
x_grid = np.linspace(0,180,300)
y_grid = np.linspace(1,7,300)
X,Y = np.meshgrid(x_grid,y_grid)
positions = np.vstack([X.ravel(),Y.ravel()])

# figure setup
fig, axes = plt.subplots(2,3,figsize=(9,6),sharex=True,sharey=True)
cmap = plt.get_cmap("YlGnBu")
norm = mcolors.Normalize(vmin=0,vmax=6)
levels = np.linspace(0,6,13)

for ax,sys in zip(axes.flat,systems):

    *interactions,title = sys

    for entry in interactions:

        if len(entry)==3:
            dat_file,label,coords = entry
        else:
            dat_file,label = entry
            coords=None

        data = np.loadtxt(dat_file,comments=('#','@'))

        if data.ndim==1:
            dist=np.array([data[1]])
            angle=np.array([data[2]])
        else:
            dist=data[:,1]
            angle=data[:,2]

        values=np.vstack([angle,dist])

        kde=gaussian_kde(values)
        kde.set_bandwidth(bw_method=kde.factor*0.4)

        # KDE probability
        P=kde(positions).reshape(X.shape)

        # free energy
        F=-R*T*np.log(P+eps)   

        # shift minimum
        F=F-F.min()

        cf=ax.contourf(X,Y,F,
                       levels=levels,
                       cmap=cmap,
                       norm=norm)

        ax.contour(X,Y,F,
                   levels=levels,
                   colors="k",
                   linewidths=0.4)

        if coords:
            ax.text(coords[0],coords[1],
                    label,
                    fontsize=10,
                    weight="bold")

    ax.set_title(title, fontsize=16, weight="bold")

# axes labels
for ax in axes[1, :]:
    ax.set_xlabel("angle (°)", fontsize=14, weight="bold")
for ax in axes[:, 0]:
    ax.set_ylabel("distance (Å)", fontsize=14, weight="bold")

# colorbar
fig.tight_layout(rect=[0, 0, 0.92, 1])
fig.colorbar(cf,
             ax=axes.ravel().tolist(),
             fraction=0.046,
             pad=0.04,
             label="Free energy (kcal/mol)")

plt.savefig("MXH_FES.jpg",dpi=300)
plt.show()
